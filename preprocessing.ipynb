# %% [markdown]
# Import Libraries

# %%
# Python Demo

# %%
a=8
b=4
c=a*b
print(c)
if(a>b):
    print(a,"is greater")
else:
    print(b,"is greater")
# Out:
# 32
# 8 is greater

# %%
n=6
fact=1
for i in range(1,n+1):
    fact=fact*i
print(fact)
# Out:
# 720

# %%
# while loop demo
# extract 3 by using x%10
x=123
sum=0
while(x!=0):
    sum=sum+(x%10)
    x=x/10
print(int(sum))
# Out:
# 6

# %%
import pandas as pd
import numpy as np

# %%
# create header for dataset
header = ['age','bp','sg','al','su','rbc','pc','pcc',
    'ba','bgr','bu','sc','sod','pot','hemo','pcv',
    'wbcc','rbcc','htn','dm','cad','appet','pe','ane',
    'classification']
# read the dataset
df = pd.read_csv("C://Users//ROHINI//Desktop//CIT//chronic_kidney_disease.arff",names=header)
print(df)
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 0    48   80  1.020  1  0         ?    normal  notpresent  notpresent  121
# 1     7   50  1.020  4  0         ?    normal  notpresent  notpresent    ?
# 2    62   80  1.010  2  3    normal    normal  notpresent  notpresent  423
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 4    51   80  1.010  2  0    normal    normal  notpresent  notpresent  106
# 5    60   90  1.015  3  0         ?         ?  notpresent  notpresent   74
# 6    68   70  1.010  0  0         ?    normal  notpresent  notpresent  100
# 7    24    ?  1.015  2  4    normal  abnormal  notpresent  notpresent  410
# 8    52  100  1.015  3  0    normal  abnormal     present  notpresent  138
# 9    53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 10   50   60  1.010  2  4         ?  abnormal     present  notpresent  490
# ...

# %%
# dataset has '?' in it, convert these into NaN
df = df.replace('?', np.nan)
# drop the NaN
df = df.dropna(axis=0, how="any")
print(df)
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 9    53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 11   63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# 14   68   80  1.010  3  2    normal  abnormal     present     present  157
# 20   61   80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
# 22   48   80  1.025  4  0    normal  abnormal  notpresent  notpresent   95
# 27   69   70  1.010  3  4    normal  abnormal  notpresent  notpresent  264
# 48   73   70  1.005  0  0    normal    normal  notpresent  notpresent   70
# 58   73   80  1.020  2  0  abnormal  abnormal  notpresent  notpresent  253
# 71   46   60  1.010  1  0    normal    normal  notpresent  notpresent  163
# 74   56   90  1.015  2  0  abnormal  abnormal  notpresent  notpresent  129
# ...

# %%
# print total samples
print("Total samples:", len(df))
# print 4-rows and 6-columns
print("Partial data\n", df.iloc[0:4, 0:6])
# Out:
# Total samples: 157
# Partial data
#     ahttp://localhost:8888/notebooks/Desktop//CIT//preprocessing.ipynb#age  bp  \
# 3                                                  48                      70
# 9                                                  53                      90
# 11                                                 63                      70
# 14                                                 68                      80
#
#        sg al su       rbc
# 3   1.005  4  0    normal
# 9   1.020  2  0  abnormal
# 11  1.010  3  0  abnormal
# 14  1.010  3  2    normal

# %%
df
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 9    53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 11   63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# 14   68   80  1.010  3  2    normal  abnormal     present     present  157
# 20   61   80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
# 22   48   80  1.025  4  0    normal  abnormal  notpresent  notpresent   95
# 27   69   70  1.010  3  4    normal  abnormal  notpresent  notpresent  264
# 48   73   70  1.005  0  0    normal    normal  notpresent  notpresent   70
# 58   73   80  1.020  2  0  abnormal  abnormal  notpresent  notpresent  253
# 71   46   60  1.010  1  0    normal    normal  notpresent  notpresent  163
# 74   56   90  1.015  2  0  abnormal  abnormal  notpresent  notpresent  129
# ...

# %%
df["age"] = pd.to_numeric(df["age"])

# %%
df[df["age"]>40]
# Out:
#      age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 3     48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 9     53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 11    63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# 14    68   80  1.010  3  2    normal  abnormal     present     present  157
# 20    61   80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
# 22    48   80  1.025  4  0    normal  abnormal  notpresent  notpresent   95
# 27    69   70  1.010  3  4    normal  abnormal  notpresent  notpresent  264
# 48    73   70  1.005  0  0    normal    normal  notpresent  notpresent   70
# 58    73   80  1.020  2  0  abnormal  abnormal  notpresent  notpresent  253
# 71    46   60  1.010  1  0    normal    normal  notpresent  notpresent  163
# 74    56   90  1.015  2  0  abnormal  abnormal  notpresent  notpresent  129
# ...

# %%
df[['age','bp']]
# Out:
#      age   bp
# 3     48   70
# 9     53   90
# 11    63   70
# 14    68   80
# 20    61   80
# 22    48   80
# 27    69   70
# 48    73   70
# 58    73   80
# 71    46   60
# 74    56   90
# 76    48   80
# 84    59   70
# 90    63  100
# 91    56   70
# 92    71   70
# 93    73  100
# 127   71   60
# 128   52   90
# 130   50   90
# 133   70  100
# 144   60   90
# 147   60   60
# 153   55   90
# 157   62   70
# 159   59   80
# 171   83   70
# 176   21   90
# 181   45   70
# 189   64   60
# ..   ...  ...
# 367   68   60
# 368   30   80
# 370   69   70
# 371   28   60
# 372   72   60
# 373   61   70
# 374   79   80
# 375   70   80
# 376   58   70
# 377   64   70
# 379   62   80
# 380   59   60
# 382   48   80
# 383   80   80
# 384   57   60
# 385   63   70
# 386   46   70
# 387   15   80
# 388   51   80
# 389   41   80
# 390   52   80
# 391   36   80
# 392   57   80
# 393   43   60
# 394   50   80
# 395   55   80
# 396   42   70
# 397   12   80
# 398   17   60
# 399   58   80
#
# ...

# %%
df.head(15)
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 9    53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 11   63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# 14   68   80  1.010  3  2    normal  abnormal     present     present  157
# 20   61   80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
# 22   48   80  1.025  4  0    normal  abnormal  notpresent  notpresent   95
# 27   69   70  1.010  3  4    normal  abnormal  notpresent  notpresent  264
# 48   73   70  1.005  0  0    normal    normal  notpresent  notpresent   70
# 58   73   80  1.020  2  0  abnormal  abnormal  notpresent  notpresent  253
# 71   46   60  1.010  1  0    normal    normal  notpresent  notpresent  163
# 74   56   90  1.015  2  0  abnormal  abnormal  notpresent  notpresent  129
# ...

# %%
df.tail()
# Out:
#      age  bp     sg al su     rbc      pc         pcc          ba  bgr  ...  \
# 395   55  80  1.020  0  0  normal  normal  notpresent  notpresent  140  ...
# 396   42  70  1.025  0  0  normal  normal  notpresent  notpresent   75  ...
# 397   12  80  1.020  0  0  normal  normal  notpresent  notpresent  100  ...
# 398   17  60  1.025  0  0  normal  normal  notpresent  notpresent  114  ...
# 399   58  80  1.025  0  0  normal  normal  notpresent  notpresent  131  ...
#
#     pcv  wbcc rbcc htn  dm cad appet  pe ane classification
# 395  47  6700  4.9  no  no  no  good  no  no         notckd
# 396  54  7800  6.2  no  no  no  good  no  no         notckd
# 397  49  6600  5.4  no  no  no  good  no  no         notckd
# 398  51  7200  5.9  no  no  no  good  no  no         notckd
# 399  53  6800  6.1  no  no  no  good  no  no         notckd
#
# [5 rows x 25 columns]

# %%
df[df.columns[1:4]]
# Out:
#       bp     sg al
# 3     70  1.005  4
# 9     90  1.020  2
# 11    70  1.010  3
# 14    80  1.010  3
# 20    80  1.015  2
# 22    80  1.025  4
# 27    70  1.010  3
# 48    70  1.005  0
# 58    80  1.020  2
# 71    60  1.010  1
# 74    90  1.015  2
# 76    80  1.005  4
# 84    70  1.010  3
# 90   100  1.010  2
# 91    70  1.015  4
# 92    70  1.010  3
# 93   100  1.010  3
# 127   60  1.015  4
# 128   90  1.015  4
# 130   90  1.010  2
# 133  100  1.015  4
# 144   90  1.010  2
# 147   60  1.010  3
# 153   90  1.010  2
# 157   70  1.025  3
# 159   80  1.010  1
# 171   70  1.020  3
# 176   90  1.010  4
# 181   70  1.025  2
# 189   60  1.010  4
# ..   ...    ... ..
# 367   60  1.025  0
# 368   80  1.025  0
# 370   70  1.020  0
# 371   60  1.025  0
# 372   60  1.020  0
# 373   70  1.025  0
# 374   80  1.025  0
# 375   80  1.020  0
# 376   70  1.025  0
# 377   70  1.020  0
# 379   80  1.025  0
# 380   60  1.020  0
# 382   80  1.025  0
# 383   80  1.025  0
# 384   60  1.020  0
# ...
